# %%
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LogisticRegression
import seaborn as sns
# %matplotlib inline

# %%
data  = pd.read_csv('diabetes .csv')

# %%
data
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# 5               0      173             78             32      265  46.5
# 6               4       99             72             17        0  25.6
# 7               8      194             80              0        0  26.1
# 8               2       83             65             28       66  36.8
# 9               2       89             90             30        0  33.5
# 10              4       99             68             38        0  32.8
# 11              4      125             70             18      122  28.9
# 12              3       80              0              0        0   0.0
# 13              6      166             74              0        0  26.6
# 14              5      110             68              0        0  26.0
# 15              2       81             72             15       76  30.1
# 16              7      195             70             33      145  25.1
# 17              6      154             74             32      193  29.3
# 18              2      117             90             19       71  25.2
# 19              3       84             72             32        0  37.2
# 20              6        0             68             41        0  39.0
# 21              7       94             64             25       79  33.3
# 22              3       96             78             39        0  37.3
# 23             10       75             82              0        0  33.3
# 24              0      180             90             26       90  36.5
# 25              1      130             60             23      170  28.6
# 26              2       84             50             23       76  30.4
# 27              8      120             78              0        0  25.0
# 28             12       84             72             31        0  29.7
# 29              0      139             62             17      210  22.1
# ...           ...      ...            ...            ...      ...   ...
# 1970            2       90             70             17        0  27.3
# 1971            1      136             74             50      204  37.4
# 1972            4      114             65              0        0  21.9
# 1973            9      156             86             28      155  34.3
# 1974            1      153             82             42      485  40.6
# 1975            8      188             78              0        0  47.9
# 1976            7      152             88             44        0  50.0
# 1977            2       99             52             15       94  24.6
# 1978            1      109             56             21      135  25.2
# 1979            2       88             74             19       53  29.0
# 1980           17      163             72             41      114  40.9
# 1981            4      151             90             38        0  29.7
# 1982            7      102             74             40      105  37.2
# 1983            0      114             80             34      285  44.2
# 1984            2      100             64             23        0  29.7
# 1985            0      131             88              0        0  31.6
# 1986            6      104             74             18      156  29.9
# 1987            3      148             66             25        0  32.5
# 1988            4      120             68              0        0  29.6
# 1989            4      110             66              0        0  31.9
# 1990            3      111             90             12       78  28.4
# 1991            6      102             82              0        0  30.8
# 1992            6      134             70             23      130  35.4
# 1993            2       87              0             23        0  28.9
# 1994            1       79             60             42       48  43.5
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        1
# 1                        0.233   23        0
# 2                        0.630   31        1
# 3                        0.365   24        1
# 4                        0.536   21        0
# 5                        1.159   58        0
# 6                        0.294   28        0
# 7                        0.551   67        0
# 8                        0.629   24        0
# 9                        0.292   42        0
# 10                       0.145   33        0
# 11                       1.144   45        1
# 12                       0.174   22        0
# 13                       0.304   66        0
# 14                       0.292   30        0
# 15                       0.547   25        0
# 16                       0.163   55        1
# 17                       0.839   39        0
# 18                       0.313   21        0
# 19                       0.267   28        0
# 20                       0.727   41        1
# 21                       0.738   41        0
# 22                       0.238   40        0
# 23                       0.263   38        0
# 24                       0.314   35        1
# 25                       0.692   21        0
# 26                       0.968   21        0
# 27                       0.409   64        0
# 28                       0.297   46        1
# 29                       0.207   21        0
# ...                        ...  ...      ...
# 1970                     0.085   22        0
# 1971                     0.399   24        0
# 1972                     0.432   37        0
# 1973                     1.189   42        1
# 1974                     0.687   23        0
# 1975                     0.137   43        1
# 1976                     0.337   36        1
# 1977                     0.637   21        0
# 1978                     0.833   23        0
# 1979                     0.229   22        0
# 1980                     0.817   47        1
# 1981                     0.294   36        0
# 1982                     0.204   45        0
# 1983                     0.167   27        0
# 1984                     0.368   21        0
# 1985                     0.743   32        1
# 1986                     0.722   41        1
# 1987                     0.256   22        0
# 1988                     0.709   34        0
# 1989                     0.471   29        0
# 1990                     0.495   29        0
# 1991                     0.180   36        1
# 1992                     0.542   29        1
# 1993                     0.773   25        0
# 1994                     0.678   23        0
# 1995                     0.370   33        0
# 1996                     0.719   36        1
# 1997                     0.382   42        0
# 1998                     0.319   26        1
# 1999                     0.547   25        0
#
# [2000 rows x 9 columns]

# %%
diabetes_true_count = len(data.loc[data['Outcome']==True])
diabetes_false_count = len(data.loc[data['Outcome']==False])

# %%
from sklearn.ensemble import RandomForestClassifier 
model= RandomForestClassifier(n_estimators=70,random_state=30)
X=data[data.columns[:8]]
Y=data['Outcome']
model.fit(X,Y)
pd.Series(model.feature_importances_,index=X.columns).sort_values(ascending=False)
# Out:
# Glucose                     0.263509
# BMI                         0.168478
# Age                         0.140464
# DiabetesPedigreeFunction    0.122379
# BloodPressure               0.088388
# Pregnancies                 0.075386
# Insulin                     0.071883
# SkinThickness               0.069514
# dtype: float64

# %%
from pandas.tools.plotting import scatter_matrix
p=scatter_matrix(data,figsize=(25, 25))

# %%
sns.countplot(y=data.dtypes ,data=data)
plt.xlabel("count of each data type")
plt.ylabel("data types")
plt.show()

# %%
p=sns.pairplot(data, hue = 'Outcome')

# %%
data.describe()
# Out:
#        Pregnancies      Glucose  BloodPressure  SkinThickness      Insulin  \
# count  2000.000000  2000.000000    2000.000000    2000.000000  2000.000000
# mean      3.703500   121.182500      69.145500      20.935000    80.254000
# std       3.306063    32.068636      19.188315      16.103243   111.180534
# min       0.000000     0.000000       0.000000       0.000000     0.000000
# 25%       1.000000    99.000000      63.500000       0.000000     0.000000
# 50%       3.000000   117.000000      72.000000      23.000000    40.000000
# 75%       6.000000   141.000000      80.000000      32.000000   130.000000
# max      17.000000   199.000000     122.000000     110.000000   744.000000
#
#                BMI  DiabetesPedigreeFunction          Age      Outcome
# count  2000.000000               2000.000000  2000.000000  2000.000000
# mean     32.193000                  0.470930    33.090500     0.342000
# std       8.149901                  0.323553    11.786423     0.474498
# min       0.000000                  0.078000    21.000000     0.000000
# 25%      27.375000                  0.244000    24.000000     0.000000
# 50%      32.300000                  0.376000    29.000000     0.000000
# 75%      36.800000                  0.624000    40.000000     1.000000
# max      80.600000                  2.420000    81.000000     1.000000

# %%
data[['Insulin','Age']].head(10)
# Out:
#    Insulin  Age
# 0        0   47
# 1      125   23
# 2        0   31
# 3      250   24
# 4      480   21
# 5      265   58
# 6        0   28
# 7        0   67
# 8       66   24
# 9        0   42

# %%
data.head(10).T
# Out:
#                                 0        1       2        3        4        5  \
# Pregnancies                 2.000    0.000    0.00    0.000    1.000    0.000
# Glucose                   138.000   84.000  145.00  135.000  139.000  173.000
# BloodPressure              62.000   82.000    0.00   68.000   62.000   78.000
# SkinThickness              35.000   31.000    0.00   42.000   41.000   32.000
# Insulin                     0.000  125.000    0.00  250.000  480.000  265.000
# BMI                        33.600   38.200   44.20   42.300   40.700   46.500
# DiabetesPedigreeFunction    0.127    0.233    0.63    0.365    0.536    1.159
# Age                        47.000   23.000   31.00   24.000   21.000   58.000
# Outcome                     1.000    0.000    1.00    1.000    0.000    0.000
#
#                                6        7       8       9
# Pregnancies                4.000    8.000   2.000   2.000
# Glucose                   99.000  194.000  83.000  89.000
# BloodPressure             72.000   80.000  65.000  90.000
# SkinThickness             17.000    0.000  28.000  30.000
# Insulin                    0.000    0.000  66.000   0.000
# BMI                       25.600   26.100  36.800  33.500
# DiabetesPedigreeFunction   0.294    0.551   0.629   0.292
# Age                       28.000   67.000  24.000  42.000
# Outcome                    0.000    0.000   0.000   0.000

# %%
data.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
data.shape
# Out:
# (2000, 9)

# %%
data.tail()
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 1995                     0.370   33        0
# 1996                     0.719   36        1
# 1997                     0.382   42        0
# 1998                     0.319   26        1
# 1999                     0.547   25        0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
# Pregnancies                 2000 non-null int64
# Glucose                     2000 non-null int64
# BloodPressure               2000 non-null int64
# SkinThickness               2000 non-null int64
# Insulin                     2000 non-null int64
# BMI                         2000 non-null float64
# DiabetesPedigreeFunction    2000 non-null float64
# Age                         2000 non-null int64
# Outcome                     2000 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 140.7 KB

# %%
feature_columns = ['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']
predicted_class = ['Outcome']

# %%
x = data[feature_columns].values
y = data[predicted_class].values

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state=10)

# %%
print("totale number of rows : {0}".format(len(data)))
print("number of rows missing Pregnancies:{0}".format(len(data.loc[data['Pregnancies']==0])))
print("number of rows missing Glucose:{0}".format(len(data.loc[data['Glucose']==0])))
print("number of rows missing BloodPressure:{0}".format(len(data.loc[data['BloodPressure']==0])))
print("number of rows missing SkinThickness:{0}".format(len(data.loc[data['SkinThickness']==0])))
print("number of rows missing Insulin:{0}".format(len(data.loc[data['Insulin']==0])))
print("number of rows missing BMI:{0}".format(len(data.loc[data['BMI']==0])))
print("number of rows missing DiabetesPedigreeFunction:{0}".format(len(data.loc[data['DiabetesPedigreeFunction']==0])))
print("number of rows missing Age:{0}".format(len(data.loc[data['Age']==0])))
# Out:
# totale number of rows : 2000
# number of rows missing Pregnancies:301
# number of rows missing Glucose:13
# number of rows missing BloodPressure:90
# number of rows missing SkinThickness:573
# number of rows missing Insulin:956
# number of rows missing BMI:28
# number of rows missing DiabetesPedigreeFunction:0
# number of rows missing Age:0

# %%
for col in feature_columns:
    data[col].replace(0, np.NaN, inplace=True)
    
data.describe()
# Out:
# C:\Users\Fawzia Akbari\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        Pregnancies      Glucose  BloodPressure  SkinThickness      Insulin  \
# count  1699.000000  1987.000000    1910.000000    1427.000000  1044.000000
# mean      4.359623   121.975340      72.403665      29.341275   153.743295
# std       3.163141    30.632883      12.227968      10.802278   111.273639
# min       1.000000    44.000000      24.000000       7.000000    14.000000
# 25%            NaN          NaN            NaN            NaN          NaN
# 50%            NaN          NaN            NaN            NaN          NaN
# 75%            NaN          NaN            NaN            NaN          NaN
# max      17.000000   199.000000     122.000000     110.000000   744.000000
#
#                BMI  DiabetesPedigreeFunction          Age      Outcome
# count  1972.000000               2000.000000  2000.000000  2000.000000
# mean     32.650101                  0.470930    33.090500     0.342000
# std       7.241027                  0.323553    11.786423     0.474498
# min      18.200000                  0.078000    21.000000     0.000000
# 25%            NaN                  0.244000    24.000000     0.000000
# 50%            NaN                  0.376000    29.000000     0.000000
# 75%            NaN                  0.624000    40.000000     1.000000
# max      80.600000                  2.420000    81.000000     1.000000

# %%
data.dropna(inplace=True)

# summarize the number of rows and columns in df
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   876.000000  876.000000      876.00000     876.000000  876.000000
# mean      3.763699  122.493151       70.34589      28.738584  153.481735
# std       3.110918   30.553316       12.18459      10.267237  111.354008
# min       1.000000   56.000000       24.00000       7.000000   15.000000
# 25%       1.000000   99.000000       62.00000      21.000000   76.000000
# 50%       3.000000  120.000000       71.00000      28.500000  126.000000
# 75%       5.000000  144.000000       78.00000      36.000000  185.000000
# max      17.000000  197.000000      110.00000      59.000000  744.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  876.000000                876.000000  876.000000  876.000000
# mean    32.553653                  0.522707   31.545662    0.328767
# std      6.434503                  0.323098   10.188687    0.470034
# min     18.200000                  0.085000   21.000000    0.000000
# 25%     28.300000                  0.280000   24.000000    0.000000
# 50%     32.900000                  0.453000   28.000000    0.000000
# 75%     36.525000                  0.687000   37.250000    1.000000
# max     57.300000                  2.329000   81.000000    1.000000

# %%
data['Age'] = data['Age'].astype('object')
print(data.Age.value_counts())


age_dict = {1:5, 2:15, 3:25, 4:35, 5:45, 6:55, 7:65, 8:75, 9:85, 10:95}
data['Age'] = data.Age.map(age_dict)
print(data.Age.value_counts())
# Out:
# 22    85
# 24    68
# 25    65
# 23    64
# 28    57
# 21    55
# 26    44
# 29    35
# 30    29
# 31    28
# 27    26
# 43    25
# 39    22
# 36    20
# 33    19
# 34    19
# 42    19
# 37    19
# 46    17
# 40    16
# 45    14
# 32    12
# 35    12
# 41    11
# 38    10
# 47     9
# 48     9
# 51     9
# 58     8
# 55     7
# 49     6
# 54     5
# 50     5
# 63     5
# 53     4
# 52     4
# 60     3
# 81     3
# 56     2
# 57     2
# 44     2
# 61     2
# Name: Age, dtype: int64
# Series([], Name: Age, dtype: int64)

# %%
#apply algorithm
model = RandomForestClassifier(n_estimators=1000)

#fiting the model
model.fit(x_train, y_train)

#prediction
y_pred = model.predict(x_test)

#accuracy
print("Accuracy -- >", model.score(x_test, y_test)*100)
# Out:
# C:\Users\Fawzia Akbari\Anaconda3\lib\site-packages\ipykernel\__main__.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Accuracy -- > 96.3333333333

# %%
# Convert dataframe to numpy array
dataset = data.values
print(dataset.shape)
# Out:
# (876, 9)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler().fit(x)

# %%
x = dataset[:,0:8]
y = dataset[:, 8]

# %%
x_test = scaler.transform(x)

data = pd.DataFrame(x_test)
data.describe()
# Out:
#                 0           1           2           3           4           5  \
# count  876.000000  876.000000  876.000000  876.000000  876.000000  876.000000
# mean     0.018213    0.040880    0.062574    0.484718    0.658803    0.044264
# std      0.941209    0.952986    0.635159    0.637748    1.001811    0.789717
# min     -0.817945   -2.033102   -2.353348   -0.865570   -0.587066   -1.717383
# 25%     -0.817945   -0.691892   -0.372481    0.004037   -0.038272   -0.477794
# 50%     -0.212844   -0.036883    0.096672    0.469899    0.411560    0.086771
# 75%      0.392256    0.711699    0.461568    0.935760    0.942361    0.531673
# max      4.022859    2.364817    2.129667    2.364401    5.971477    3.081421
#
#                 6           7
# count  876.000000  876.000000
# mean     0.160065   -0.131102
# std      0.998844    0.864659
# min     -1.193088   -1.026055
# 25%     -0.590253   -0.771462
# 50%     -0.055430   -0.432003
# 75%      0.667972    0.352994
# max      5.744151    4.065821

# %%
p = data.hist(figsize = (20,20))

# %%
data.isnull().values.any()
# Out:
# False

# %%
random_forest_model = RandomForestClassifier(random_state=10)
random_forest_model.fit(x_train,y_train.ravel())
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=10, verbose=0, warm_start=False)

# %%
L1 = np.random.randint(1,10,20)
L2 = np.random.randint(1,20,20)

datafram = pd.DataFrame()
datafram['L1'] = L1
datafram['L2'] = L2

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
datafram = pd.DataFrame(scaler.fit_transform(datafram), columns = ['L1','l2'])
datafram.corr()
# Out:
#           L1        l2
# L1  1.000000  0.132535
# l2  0.132535  1.000000

# %%
data.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# 5    float64
# 6    float64
# 7    float64
# dtype: object
